# %%
import json
with open('/Users/danielbarella/.secret/yelp_api.json') as f: #change the path to match YOUR path!!
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# import the YelpAPI Class
from yelpapi import YelpAPI
# Create an instance with your key
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %%
help(yelp_api.search_query)
# Out:
# Help on method search_query in module yelpapi.yelpapi:
#
# search_query(**kwargs) method of yelpapi.yelpapi.YelpAPI instance
#     Query the Yelp Search API.
#
#     documentation: https://www.yelp.com/developers/documentation/v3/business_search
#
#     required parameters:
#         * one of either:
#             * location - text specifying a location to search for
#             * latitude and longitude

# %%
# use our yelp_api variable's search_query method to perform our API call
search_results = yelp_api.search_query(location='NY, NY',
                                       term='Pizza')
print(type(search_results))
search_results.keys()
# Out:
# <class 'dict'>
# dict_keys(['businesses', 'total', 'region'])

# %%
search_results['total']
# Out:
# 16600

# %%
import pandas as pd
biz = pd.DataFrame(search_results['businesses'])
biz.head(2)
# Out:
#                        id                           alias  \
# 0  zj8Lq1T8KIC5zwFief15jg  prince-street-pizza-new-york-2
# 1  ysqgdbSrezXgVwER2kQWKA             julianas-brooklyn-3
#
#                   name                                          image_url  \
# 0  Prince Street Pizza  https://s3-media2.fl.yelpcdn.com/bphoto/I4gm7i...
# 1            Juliana's  https://s3-media2.fl.yelpcdn.com/bphoto/NVoLFl...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/prince-street-pizza-n...          4745
# 1      False  https://www.yelp.com/biz/julianas-brooklyn-3?a...          2601
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 1             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 40.72308755605564, 'longitude': -...  [delivery, pickup]
# 1  {'latitude': 40.70274718768062, 'longitude': -...          [delivery]
#
#   price                                           location         phone  \
# 0     $  {'address1': '27 Prince St', 'address2': None,...  +12129664100
# 1    $$  {'address1': '19 Old Fulton St', 'address2': '...  +17185966700
#
#     display_phone     distance
# 0  (212) 966-4100  2209.311618
# 1  (718) 596-6700  1289.857286

# %%
## total number of matching businesses
search_results['total']
# Out:
# 16600

# %%
## how many businesses in our results
len(search_results['businesses'])
# Out:
# 20

# %%
# add offset to our original api call
search_results = yelp_api.search_query(location='NY, NY',
                                       term='Pizza',
                                       offset = 20)

# %%
biz20 = pd.DataFrame(search_results['businesses'])
biz20.head(2)
# Out:
#                        id                         alias               name  \
# 0  FhXjAc6nKLf414KxYujUHw           robertas-brooklyn-2          Roberta's
# 1  bB5b8cj0yWNJvmmLiQeWGA  piccolo-trattoria-new-york-2  Piccolo Trattoria
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/8fY9fA...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/00Umc7...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/robertas-brooklyn-2?a...          3229
# 1  https://www.yelp.com/biz/piccolo-trattoria-new...           116
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 1             [{'alias': 'pizza', 'title': 'Pizza'}]     3.0
#
#                                          coordinates        transactions  \
# 0     {'latitude': 40.70493, 'longitude': -73.93399}  [pickup, delivery]
# 1  {'latitude': 40.7591676767848, 'longitude': -7...  [pickup, delivery]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '261 Moore St', 'address2': '', '...  +17184171118
# 1     $  {'address1': '455 Main St', 'address2': '', 'a...  +12127532300
#
#     display_phone     distance
# 0  (718) 417-1118  3816.592615
# 1  (212) 753-2300  6222.244915

# %%
## concatenate the previous results and new results. 
businesses = pd.concat([biz, biz20],
                      ignore_index=True)
display(businesses.head(3), businesses.tail(3))
# Out:
#                        id                           alias  \
# 0  zj8Lq1T8KIC5zwFief15jg  prince-street-pizza-new-york-2
# 1  ysqgdbSrezXgVwER2kQWKA             julianas-brooklyn-3
# 2  WG639VkTjmK5dzydd1BBJA             rubirosa-new-york-2
#
#                   name                                          image_url  \
# 0  Prince Street Pizza  https://s3-media2.fl.yelpcdn.com/bphoto/I4gm7i...
# 1            Juliana's  https://s3-media2.fl.yelpcdn.com/bphoto/NVoLFl...
# 2             Rubirosa  https://s3-media4.fl.yelpcdn.com/bphoto/LuSzR8...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/prince-street-pizza-n...          4745
# 1      False  https://www.yelp.com/biz/julianas-brooklyn-3?a...          2601
# 2      False  https://www.yelp.com/biz/rubirosa-new-york-2?a...          2903
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 1             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 2  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 40.72308755605564, 'longitude': -...  [delivery, pickup]
# 1  {'latitude': 40.70274718768062, 'longitude': -...          [delivery]
# 2   {'latitude': 40.722766, 'longitude': -73.996233}            [pickup]
#
#   price                                           location         phone  \
# 0     $  {'address1': '27 Prince St', 'address2': None,...  +12129664100
# 1    $$  {'address1': '19 Old Fulton St', 'address2': '...  +17185966700
# 2    $$  {'address1': '235 Mulberry St', 'address2': ''...  +12129650500
#
#     display_phone     distance
# 0  (212) 966-4100  2209.311618
# 1  (718) 596-6700  1289.857286
# 2  (212) 965-0500  2268.491950
#                         id                                    alias  \
# 37  4MIHutYjIwoXsi-R8TlrSg      andrew-belluccis-pizzeria-astoria-4
# 38  15k7iqFbhf4h8L01yggLqg                   song-e-napule-new-york
# 39  S4uozcDEieoaXxIJ6TsUoQ  dellaroccos-brick-oven-pizza-brooklyn-2
#
#                              name  \
# 37     Andrew Bellucci's Pizzeria
# 38                  Song E Napule
# 39  Dellarocco's Brick Oven Pizza
#
#                                             image_url  is_closed  \
# 37  https://s3-media4.fl.yelpcdn.com/bphoto/U4Gllu...      False
# 38  https://s3-media2.fl.yelpcdn.com/bphoto/y9G-nh...      False
# 39  https://s3-media1.fl.yelpcdn.com/bphoto/spXNRL...      False
#
#                                                   url  review_count  \
# 37  https://www.yelp.com/biz/andrew-belluccis-pizz...           106
# 38  https://www.yelp.com/biz/song-e-napule-new-yor...           667
# 39  https://www.yelp.com/biz/dellaroccos-brick-ove...           343
#
#                                            categories  rating  \
# 37             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 38  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 39  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
#
#                                           coordinates        transactions  \
# 37  {'latitude': 40.76436969988826, 'longitude': -...  [pickup, delivery]
# 38     {'latitude': 40.72813, 'longitude': -74.00188}  [pickup, delivery]
# 39  {'latitude': 40.6950309, 'longitude': -73.9961...  [pickup, delivery]
#
#    price                                           location         phone  \
# 37   NaN  {'address1': '37-08 30th Ave', 'address2': '',...  +17184072497
# 38    $$  {'address1': '146 W Houston St', 'address2': N...  +12125331242
# 39    $$  {'address1': '214 Hicks St', 'address2': None,...  +17188581010
#
#      display_phone     distance
# 37  (718) 407-2497  8287.263821
# 38  (212) 533-1242  3034.286450
# 39  (718) 858-1010  1950.750202
